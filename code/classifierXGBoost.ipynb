# %% [markdown]
# # IZBACI XEVE I NADJI NAJBOLJI ATRIBUT

# %%
import os
from Bio import SeqIO
from sklearn.preprocessing import LabelEncoder
from collections import Counter
import xgboost as xgb
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import numpy as np


def train_xgboost(direct_folder, train_folder, test_folder,
                  report_file = None,
                  num_boost_round = 100, top_features = 20):
    """
    Train and evaluate XGBoost on protein sequences using repeat counts as features.
    
    Args:
        direct_folder (str): Folder with repeats (comma-separated format: label,repeat,...).
        train_folder (str): Folder with training FASTA sequences.
        test_folder (str): Folder with testing FASTA sequences.
        report_file (str): Path to save classification report.
        num_boost_round (int): Number of boosting rounds.
        top_features (int): Number of most important features to display/plot.
    
    Returns:
        model: trained XGBoost model
        encoder: fitted LabelEncoder
        known_repeats: list of feature names
    """

    # -----------------------------
    # 1️⃣ Load known repeats
    repeats = []
    for file in os.listdir(direct_folder):
        if file.startswith("."):
            continue
        with open(os.path.join(direct_folder, file), "r") as f:
            for line in f:
                parts = line.strip().split(",")
                if len(parts) >= 2:
                    repeats.append(parts[1])

    known_repeats = list(set(r for r in repeats if "X" not in r))
    known_repeats = list(set(r for r in known_repeats if "N" not in r))
    print(f"Number of unique repeats: {len(known_repeats)}")

    def extract_repeat_counts(sequence, repeat_list):
        return [sequence.count(r) for r in repeat_list]

    # -----------------------------
    # 2️⃣ Stream training set
    X_train, y_train = [], []
    for file in os.listdir(train_folder):
        if file.startswith("."):
            continue
        filepath = os.path.join(train_folder, file)
        for record in SeqIO.parse(filepath, "fasta"):
            X_train.append(extract_repeat_counts(str(record.seq), known_repeats))
            y_train.append(file.replace(".fasta", ""))

    # -----------------------------
    # 3️⃣ Stream testing set
    X_test, y_test = [], []
    for file in os.listdir(test_folder):
        if file.startswith("."):
            continue
        filepath = os.path.join(test_folder, file)
        for record in SeqIO.parse(filepath, "fasta"):
            X_test.append(extract_repeat_counts(str(record.seq), known_repeats))
            y_test.append(file.replace(".fasta", ""))

    # -----------------------------
    # 4️⃣ Encode labels
    encoder = LabelEncoder()
    y_train_enc = encoder.fit_transform(y_train)
    y_test_enc = encoder.transform(y_test)

    # -----------------------------
    # 5️⃣ Sample weights
    counter = Counter(y_train_enc)
    total = sum(counter.values())
    weights = {cls: total / count for cls, count in counter.items()}
    sample_weights = [weights[label] for label in y_train_enc]

    # -----------------------------
    # 6️⃣ Prepare DMatrix
    dtrain = xgb.DMatrix(X_train, label=y_train_enc, weight=sample_weights, feature_names=known_repeats)
    dtest = xgb.DMatrix(X_test, label=y_test_enc, feature_names=known_repeats)

    # -----------------------------
    # 7️⃣ Train model
    num_classes = len(encoder.classes_)
    params = {
        "objective": "multi:softprob",
        "num_class": num_classes,
        "eval_metric": "mlogloss",
        "seed": 42,
    }
    model = xgb.train(params, dtrain, num_boost_round=num_boost_round)

    # -----------------------------
    # 8️⃣ Predictions
    y_pred_probs = model.predict(dtest)
    y_pred_enc = y_pred_probs.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred_enc)

    y_pred_probs_train = model.predict(dtrain)
    y_pred_enc_train = y_pred_probs_train.argmax(axis=1)
    y_pred_train = encoder.inverse_transform(y_pred_enc_train)

    # -----------------------------
    # 9️⃣ Report
    report = classification_report(y_test, y_pred)
    print("Classification report:")
    print(report)
    print("Accuracy score test:", accuracy_score(y_test, y_pred))
    print("Accuracy score train:", accuracy_score(y_train, y_pred_train))

    with open(report_file, "w") as f:
        f.write(report)
        f.write("\nAccuracy score test: " + str(accuracy_score(y_test, y_pred)))
        f.write("\nAccuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

    # -----------------------------
    # 🔟 Feature importances
    importance_dict = model.get_score(importance_type="weight")  # you can also use "gain" or "cover"
    # Convert dict to sorted list
    sorted_importances = sorted(importance_dict.items(), key=lambda x: x[1], reverse=True)

    print(f"\nTop {top_features} most important features (repeats):")
    for i, (feat, val) in enumerate(sorted_importances[:top_features], 1):
        print(f"{i}. {feat}: {val:.4f}")

    # Plot
    features, scores = zip(*sorted_importances[:top_features])
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(features)), scores, align="center")
    plt.xticks(range(len(features)), features, rotation=90)
    plt.title(f"Top {top_features} Important Repeats (XGBoost)")
    plt.ylabel("Importance (weight)")
    plt.tight_layout()
    plt.show()

    return model, encoder, known_repeats

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2/direct",
    train_folder="../trainSet",
    test_folder="../testSet",
    report_file="classification_report_xgb_direct_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 990
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      1.00      1.00       153
#    HCoV-HKU1       1.00      0.99      0.99       100
#    HCoV-NL63       0.99      1.00      1.00       213
#    HCoV-OC43       1.00      0.99      1.00       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      1.00      1.00       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      1.00      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       0.99      0.99      0.99       375
#   canine-CoV       0.95      0.97      0.96       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       0.35      1.00      0.52         8
#   feline-CoV       1.00      0.98      0.99       536
#   ferret-CoV       1.00      1.00      1.00        13
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2/indirect",
    train_folder="../trainSet",
    test_folder="../testSet",
    report_file="classification_report_xgb_indirect_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 1495
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      1.00      1.00       153
#    HCoV-HKU1       1.00      1.00      1.00       100
#    HCoV-NL63       1.00      1.00      1.00       213
#    HCoV-OC43       1.00      0.99      0.99       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      0.99      1.00       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      0.99      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       0.99      0.99      0.99       375
#   canine-CoV       0.97      0.96      0.97       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       0.78      0.88      0.82         8
#   feline-CoV       0.94      0.99      0.97       536
#   ferret-CoV       1.00      0.92      0.96        13
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicates/direct",
    train_folder="../trainSetNoDuplicates",
    test_folder="../testSetNoDuplicates",
    report_file="classification_report_xgb_direct_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 982
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.97      0.98        94
#    HCoV-HKU1       1.00      0.98      0.99        56
#    HCoV-NL63       0.99      1.00      1.00       103
#    HCoV-OC43       1.00      0.99      1.00       196
#          IBV       1.00      1.00      1.00      2097
#     MERS-CoV       0.99      0.98      0.99       138
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       1.00      0.99      1.00       661
#      bat-CoV       0.92      1.00      0.96        12
#   bovine-CoV       1.00      1.00      1.00       245
#   canine-CoV       0.88      0.94      0.91       143
#  dolphin-CoV       1.00      0.50      0.67         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.98      0.99      0.98       389
#   ferret-CoV       0.82      1.00      0.90         9
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicates/indirect",
    train_folder="../trainSetNoDuplicates",
    test_folder="../testSetNoDuplicates",
    report_file="classification_report_xgb_indirect_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 1478
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.98      0.99        94
#    HCoV-HKU1       1.00      0.95      0.97        56
#    HCoV-NL63       0.98      1.00      0.99       103
#    HCoV-OC43       0.99      0.99      0.99       196
#          IBV       1.00      1.00      1.00      2097
#     MERS-CoV       1.00      0.99      0.99       138
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       1.00      0.99      1.00       661
#      bat-CoV       0.92      1.00      0.96        12
#   bovine-CoV       0.99      0.99      0.99       245
#   canine-CoV       0.96      0.95      0.96       143
#  dolphin-CoV       1.00      1.00      1.00         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.96      0.99      0.97       389
#   ferret-CoV       1.00      0.89      0.94         9
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicatesNucl/DC",
    train_folder="../trainSetNoDuplicatesNucl",
    test_folder="../testSetNoDuplicatesNucl",
    report_file="classification_report_xgb_DC_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 4509
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.99      1.00       120
#    HCoV-HKU1       1.00      0.99      0.99        70
#    HCoV-NL63       1.00      1.00      1.00       154
#    HCoV-OC43       1.00      0.99      1.00       252
#          IBV       1.00      0.99      1.00      2267
#     MERS-CoV       1.00      0.99      0.99       198
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       0.96      1.00      0.98       624
#      bat-CoV       1.00      1.00      1.00        13
#   bovine-CoV       0.99      1.00      0.99       276
#   canine-CoV       0.95      0.97      0.96       162
#  dolphin-CoV       1.00      1.00      1.00         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.99      0.96      0.97       444
#   ferret-CoV       1.00      0.91      0.95        11
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicatesNucl/DN",
    train_folder="../trainSetNoDuplicatesNucl",
    test_folder="../testSetNoDuplicatesNucl",
    report_file="classification_report_xgb_DN_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 8047
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.99      1.00       120
#    HCoV-HKU1       1.00      0.99      0.99        70
#    HCoV-NL63       1.00      1.00      1.00       154
#    HCoV-OC43       1.00      0.99      0.99       252
#          IBV       1.00      1.00      1.00      2267
#     MERS-CoV       1.00      0.99      0.99       198
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       0.97      1.00      0.99       624
#      bat-CoV       1.00      1.00      1.00        13
#   bovine-CoV       1.00      1.00      1.00       276
#   canine-CoV       0.96      0.93      0.94       162
#  dolphin-CoV       1.00      1.00      1.00         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.98      0.97      0.98       444
#   ferret-CoV       1.00      0.91      0.95        11
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicatesNucl/IC",
    train_folder="../trainSetNoDuplicatesNucl",
    test_folder="../testSetNoDuplicatesNucl",
    report_file="classification_report_xgb_IC_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 6144
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.99      1.00       120
#    HCoV-HKU1       1.00      0.99      0.99        70
#    HCoV-NL63       1.00      1.00      1.00       154
#    HCoV-OC43       1.00      1.00      1.00       252
#          IBV       1.00      1.00      1.00      2267
#     MERS-CoV       1.00      0.99      0.99       198
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       0.97      1.00      0.99       624
#      bat-CoV       1.00      1.00      1.00        13
#   bovine-CoV       1.00      0.99      0.99       276
#   canine-CoV       0.96      0.94      0.95       162
#  dolphin-CoV       1.00      1.00      1.00         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.98      0.98      0.98       444
#   ferret-CoV       0.92      1.00      0.96        11
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba2NoDuplicatesNucl/IN",
    train_folder="../trainSetNoDuplicatesNucl",
    test_folder="../testSetNoDuplicatesNucl",
    report_file="classification_report_xgb_IN_no_duplicates_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 6346
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      1.00      1.00       120
#    HCoV-HKU1       1.00      0.99      0.99        70
#    HCoV-NL63       1.00      1.00      1.00       154
#    HCoV-OC43       1.00      0.99      1.00       252
#          IBV       1.00      1.00      1.00      2267
#     MERS-CoV       1.00      0.98      0.99       198
#     SARS-CoV       1.00      1.00      1.00         2
#    SARS-CoV2       0.97      1.00      0.99       624
#      bat-CoV       1.00      1.00      1.00        13
#   bovine-CoV       0.99      1.00      1.00       276
#   canine-CoV       0.97      0.96      0.97       162
#  dolphin-CoV       1.00      1.00      1.00         2
#   equine-CoV       1.00      0.86      0.92         7
#   feline-CoV       0.99      0.97      0.98       444
#   ferret-CoV       1.00      0.91      0.95        11
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba3/DC",
    train_folder="../trainSetNucl",
    test_folder="../testSetNucl",
    report_file="classification_report_xgb_DC_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 6993
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.98      0.99       153
#    HCoV-HKU1       1.00      1.00      1.00       100
#    HCoV-NL63       1.00      1.00      1.00       213
#    HCoV-OC43       1.00      0.99      1.00       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      0.98      0.99       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      1.00      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       1.00      1.00      1.00       375
#   canine-CoV       0.96      0.98      0.97       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       1.00      0.50      0.67         8
#   feline-CoV       0.96      0.99      0.97       536
#   ferret-CoV       1.00      0.92      0.96        13
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba3/DN",
    train_folder="../trainSetNucl",
    test_folder="../testSetNucl",
    report_file="classification_report_xgb_DN_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 11921
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.98      0.99       153
#    HCoV-HKU1       0.99      1.00      1.00       100
#    HCoV-NL63       1.00      1.00      1.00       213
#    HCoV-OC43       1.00      1.00      1.00       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      0.99      1.00       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      1.00      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       1.00      1.00      1.00       375
#   canine-CoV       0.96      0.99      0.97       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       1.00      0.50      0.67         8
#   feline-CoV       0.99      0.99      0.99       536
#   ferret-CoV       0.80      0.92      0.86        13
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba3/IC",
    train_folder="../trainSetNucl",
    test_folder="../testSetNucl",
    report_file="classification_report_xgb_IC_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 9112
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.98      0.99       153
#    HCoV-HKU1       1.00      0.99      0.99       100
#    HCoV-NL63       0.99      1.00      1.00       213
#    HCoV-OC43       1.00      1.00      1.00       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      0.98      0.99       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      1.00      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       1.00      1.00      1.00       375
#   canine-CoV       0.96      1.00      0.98       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       1.00      0.50      0.67         8
#   feline-CoV       0.97      0.99      0.98       536
#   ferret-CoV       0.87      1.00      0.93        13
# ...

# %%
model, encoder, repeats = train_xgboost(
    direct_folder="../proba3/IN",
    train_folder="../trainSetNucl",
    test_folder="../testSetNucl",
    report_file="classification_report_xgb_IN_2.txt",
    num_boost_round=100,
    top_features=10
)
# Out:
# Number of unique repeats: 9258
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.98      0.99       153
#    HCoV-HKU1       0.99      1.00      1.00       100
#    HCoV-NL63       1.00      1.00      1.00       213
#    HCoV-OC43       1.00      1.00      1.00       366
#          IBV       1.00      1.00      1.00      3149
#     MERS-CoV       1.00      0.98      0.99       395
#     SARS-CoV       1.00      1.00      1.00         3
#    SARS-CoV2       1.00      1.00      1.00      2133
#      bat-CoV       1.00      1.00      1.00        15
#   bovine-CoV       1.00      1.00      1.00       375
#   canine-CoV       0.97      0.99      0.98       217
#  dolphin-CoV       1.00      1.00      1.00         3
#   equine-CoV       1.00      0.75      0.86         8
#   feline-CoV       0.97      0.99      0.98       536
#   ferret-CoV       1.00      0.92      0.96        13
# ...
