# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO

import os
import pandas as pd

from collections import Counter
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE
import numpy as np

# %% [markdown]
# # FINALNA VERZIJA?

# %%
from collections import Counter
from Bio import SeqIO
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

files = []
folder = "../proba2NoDuplicates/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

# Count how many times each label appears in train and test
train_counts = Counter(labelTrain)
test_counts = Counter(labelTest)

# Keep only labels with >=3 instances in both train and test
valid_labels = {label for label in train_counts if train_counts[label] >= 3 and test_counts.get(label, 0) >= 3}

# Filter training set
filtered_train = [(seq, lbl) for seq, lbl in zip(sequencesTrain, labelTrain) if lbl in valid_labels]
sequencesTrain, labelTrain = zip(*filtered_train) if filtered_train else ([], [])

# Filter test set
filtered_test = [(seq, lbl) for seq, lbl in zip(sequencesTest, labelTest) if lbl in valid_labels]
sequencesTest, labelTest = zip(*filtered_test) if filtered_test else ([], [])

# Convert back to lists
sequencesTrain = list(sequencesTrain)
labelTrain = list(labelTrain)
sequencesTest = list(sequencesTest)
labelTest = list(labelTest)

# Known repeats
known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")
print(f"Number of valid labels after filtering: {len(valid_labels)}")

# Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# Encode labels
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

# Train KNN
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')
knn.fit(X_train, y_train_enc)

# Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# Report
report = classification_report(y_test, y_pred)
print("Classification report:\n", report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score:", accuracy_score(y_test, y_pred))
print("Accuracy score train:", accuracy_score(y_train, y_pred_train))

with open("classification_report_knn_indirect_no_duplicates_no_small_classes.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: " + str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
"""
Classification report:
               precision    recall  f1-score   support

   HCoV-229E       1.00      0.93      0.96        94
   HCoV-HKU1       0.85      0.82      0.84        56
   HCoV-NL63       1.00      0.95      0.98       103
   HCoV-OC43       0.98      0.96      0.97       196
         IBV       1.00      1.00      1.00      2097
    MERS-CoV       1.00      0.96      0.98       138
   SARS-CoV2       0.96      0.99      0.98       661
     bat-CoV       1.00      1.00      1.00        12
  bovine-CoV       0.98      0.99      0.99       245
  canine-CoV       0.93      0.92      0.92       143
  equine-CoV       1.00      0.86      0.92         7
  feline-CoV       0.92      0.98      0.95       389
  ferret-CoV       1.00      0.56      0.71         9
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00        99
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.98      4290
   macro avg       0.98      0.91      0.94      4290
weighted avg       0.98      0.98      0.98      4290

Accuracy score: 0.9808857808857809
Accuracy score train: 0.9875726598516736
"""

# %%
from collections import Counter
from Bio import SeqIO
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

files = []
folder = "../proba2NoDuplicates/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

# Count how many times each label appears in train and test
train_counts = Counter(labelTrain)
test_counts = Counter(labelTest)

# Keep only labels with >=3 instances in both train and test
valid_labels = {label for label in train_counts if train_counts[label] >= 3 and test_counts.get(label, 0) >= 3}

# Filter training set
filtered_train = [(seq, lbl) for seq, lbl in zip(sequencesTrain, labelTrain) if lbl in valid_labels]
sequencesTrain, labelTrain = zip(*filtered_train) if filtered_train else ([], [])

# Filter test set
filtered_test = [(seq, lbl) for seq, lbl in zip(sequencesTest, labelTest) if lbl in valid_labels]
sequencesTest, labelTest = zip(*filtered_test) if filtered_test else ([], [])

# Convert back to lists
sequencesTrain = list(sequencesTrain)
labelTrain = list(labelTrain)
sequencesTest = list(sequencesTest)
labelTest = list(labelTest)

# Known repeats
known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")
print(f"Number of valid labels after filtering: {len(valid_labels)}")

# Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# Encode labels
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

# Train KNN
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')
knn.fit(X_train, y_train_enc)

# Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# Report
report = classification_report(y_test, y_pred)
print("Classification report:\n", report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score:", accuracy_score(y_test, y_pred))
print("Accuracy score train:", accuracy_score(y_train, y_pred_train))

with open("classification_report_knn_direct_no_duplicates_no_small_classes.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: " + str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
"""
Classification report:
               precision    recall  f1-score   support

   HCoV-229E       1.00      0.97      0.98        94
   HCoV-HKU1       0.83      0.86      0.84        56
   HCoV-NL63       1.00      0.97      0.99       103
   HCoV-OC43       0.99      0.96      0.97       196
         IBV       1.00      1.00      1.00      2097
    MERS-CoV       1.00      0.96      0.98       138
   SARS-CoV2       0.98      0.99      0.98       661
     bat-CoV       1.00      1.00      1.00        12
  bovine-CoV       0.99      0.99      0.99       245
  canine-CoV       0.94      0.94      0.94       143
  equine-CoV       1.00      0.86      0.92         7
  feline-CoV       0.97      0.98      0.97       389
  ferret-CoV       0.32      0.89      0.47         9
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00        99
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       0.83      0.83      0.83         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.98      4290
   macro avg       0.94      0.93      0.93      4290
weighted avg       0.99      0.98      0.99      4290

Accuracy score: 0.9841491841491842
Accuracy score train: 0.9909801563439568
"""

# %%
files = []
folder = "../proba2NoDuplicates/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

with open("classification_report_knn_direct_no_duplicates.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: ")
    f.write(str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: ")
    f.write(str(accuracy_score(y_train, y_pred_train)))

# %%
"""
Classification report: 
              precision    recall  f1-score   support

   HCoV-229E       1.00      0.97      0.98        94
   HCoV-HKU1       0.83      0.86      0.84        56
   HCoV-NL63       1.00      0.97      0.99       103
   HCoV-OC43       0.99      0.96      0.98       196
         IBV       1.00      1.00      1.00      2097
    MERS-CoV       1.00      0.96      0.98       138
    SARS-CoV       0.00      0.00      0.00         2
   SARS-CoV2       0.98      0.99      0.98       661
     bat-CoV       0.86      1.00      0.92        12
  bovine-CoV       0.99      1.00      0.99       245
  canine-CoV       0.94      0.91      0.92       143
 dolphin-CoV       0.00      0.00      0.00         2
  equine-CoV       1.00      0.86      0.92         7
  feline-CoV       0.97      0.98      0.97       389
  ferret-CoV       0.26      0.89      0.40         9
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00        99
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       0.83      0.83      0.83         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.98      4294
   macro avg       0.83      0.84      0.82      4294
weighted avg       0.99      0.98      0.98      4294
Accuracy score: 0.9825337680484397
Accuracy score train: 0.9907834101382489
"""
# Out:
#   Cell In[1], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
files = []
folder = "../proba2NoDuplicates/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

with open("classification_report_knn_indirect_no_duplicates.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: ")
    f.write(str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: ")
    f.write(str(accuracy_score(y_train, y_pred_train)))

# %%
"""
Classification report: 
              precision    recall  f1-score   support

   HCoV-229E       1.00      0.91      0.96        94
   HCoV-HKU1       0.87      0.80      0.83        56
   HCoV-NL63       1.00      0.95      0.98       103
   HCoV-OC43       0.98      0.96      0.97       196
         IBV       1.00      1.00      1.00      2097
    MERS-CoV       1.00      0.96      0.98       138
    SARS-CoV       0.00      0.00      0.00         2
   SARS-CoV2       0.95      0.99      0.97       661
     bat-CoV       0.86      1.00      0.92        12
  bovine-CoV       0.98      0.99      0.99       245
  canine-CoV       0.94      0.92      0.93       143
 dolphin-CoV       1.00      0.50      0.67         2
  equine-CoV       1.00      0.86      0.92         7
  feline-CoV       0.91      0.96      0.94       389
  ferret-CoV       1.00      0.56      0.71         9
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00        99
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.98      4294
   macro avg       0.92      0.84      0.87      4294
weighted avg       0.98      0.98      0.98      4294

Accuracy score: 0.9778761061946902
Accuracy score train: 0.9862752955319575
"""
# Out:
#   Cell In[2], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
files = []
folder = "../proba2/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSet/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSet/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

with open("classification_report_knn_direct.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: ")
    f.write(str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: ")
    f.write(str(accuracy_score(y_train, y_pred_train)))
# Out:
# Number of unique repeats: 2421

# %%
"""
Classification report: 
              precision    recall  f1-score   support

   HCoV-229E       0.99      0.95      0.97       153
   HCoV-HKU1       0.95      0.97      0.96       100
   HCoV-NL63       1.00      0.98      0.99       213
   HCoV-OC43       1.00      0.98      0.99       366
         IBV       1.00      1.00      1.00      3149
    MERS-CoV       0.96      0.99      0.98       395
    SARS-CoV       1.00      1.00      1.00         3
   SARS-CoV2       0.99      1.00      1.00      2133
     bat-CoV       1.00      1.00      1.00        15
  bovine-CoV       0.99      1.00      0.99       375
  canine-CoV       0.96      0.96      0.96       217
 dolphin-CoV       1.00      1.00      1.00         3
  equine-CoV       1.00      0.88      0.93         8
  feline-CoV       0.99      0.98      0.98       536
  ferret-CoV       0.80      0.92      0.86        13
hedgehog-CoV       1.00      1.00      1.00         6
 porcine-CoV       1.00      0.99      1.00       132
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       0.86      0.75      0.80         8
  turkey-CoV       1.00      1.00      1.00        27

    accuracy                           0.99      7858
   macro avg       0.97      0.95      0.96      7858
weighted avg       0.99      0.99      0.99      7858
Accuracy score: 0.9919826927971495
Accuracy score train: 0.9951382060526603
"""

# %%
files = []
folder = "../proba2/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSet/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSet/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

with open("classification_report_knn_indirect.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: ")
    f.write(str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: ")
    f.write(str(accuracy_score(y_train, y_pred_train)))

# %%
"""
Classification report: 
              precision    recall  f1-score   support

   HCoV-229E       1.00      0.92      0.96       153
   HCoV-HKU1       0.96      0.96      0.96       100
   HCoV-NL63       1.00      0.98      0.99       213
   HCoV-OC43       0.99      0.98      0.98       366
         IBV       1.00      0.99      1.00      3149
    MERS-CoV       1.00      0.99      0.99       395
    SARS-CoV       1.00      1.00      1.00         3
   SARS-CoV2       0.99      0.99      0.99      2133
     bat-CoV       1.00      1.00      1.00        15
  bovine-CoV       0.99      0.99      0.99       375
  canine-CoV       0.97      0.95      0.96       217
 dolphin-CoV       1.00      1.00      1.00         3
  equine-CoV       1.00      0.88      0.93         8
  feline-CoV       0.92      0.99      0.95       536
  ferret-CoV       1.00      0.85      0.92        13
hedgehog-CoV       1.00      1.00      1.00         6
 porcine-CoV       1.00      0.99      1.00       132
  rabbit-CoV       1.00      0.50      0.67         6
     rat-CoV       0.86      0.75      0.80         8
  turkey-CoV       1.00      1.00      1.00        27

    accuracy                           0.99      7858
   macro avg       0.98      0.94      0.95      7858
weighted avg       0.99      0.99      0.99      7858
Accuracy score: 0.988419445151438
Accuracy score train: 0.9922429804435704
"""

# %% [markdown]
# # JEDINSTVENI

# %%
import os
from collections import Counter
import numpy as np
from Bio import SeqIO
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       1.00      0.95      0.98        62
   HCoV-HKU1       0.94      0.79      0.86        42
   HCoV-NL63       1.00      0.95      0.97        74
   HCoV-OC43       0.94      0.97      0.96       159
         IBV       1.00      1.00      1.00      1242
    MERS-CoV       1.00      0.99      0.99        87
   SARS-CoV2       0.97      0.99      0.98       661
     bat-CoV       1.00      1.00      1.00         4
  bovine-CoV       0.99      0.96      0.97       161
  canine-CoV       0.93      0.92      0.92        99
  equine-CoV       1.00      0.83      0.91         6
  feline-CoV       0.99      0.99      0.99       270
  ferret-CoV       0.25      0.62      0.36         8
 porcine-CoV       1.00      1.00      1.00        57
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.25      0.40         4
  turkey-CoV       1.00      1.00      1.00        11

    accuracy                           0.98      2953
   macro avg       0.94      0.87      0.89      2953
weighted avg       0.98      0.98      0.98      2953

Accuracy score (test): 0.980697595665425
Accuracy score (train): 0.9902360827747012
"""

# %%
import os
from collections import Counter
import numpy as np
from Bio import SeqIO
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       1.00      0.92      0.96        62
   HCoV-HKU1       0.97      0.79      0.87        42
   HCoV-NL63       1.00      0.92      0.96        74
   HCoV-OC43       0.96      0.96      0.96       159
         IBV       1.00      0.99      1.00      1242
    MERS-CoV       0.97      0.99      0.98        87
   SARS-CoV2       0.93      1.00      0.96       661
     bat-CoV       1.00      1.00      1.00         4
  bovine-CoV       0.99      0.96      0.97       161
  canine-CoV       0.96      0.87      0.91        99
  equine-CoV       1.00      0.83      0.91         6
  feline-CoV       0.95      0.97      0.96       270
  ferret-CoV       1.00      0.50      0.67         8
 porcine-CoV       1.00      1.00      1.00        57
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       0.00      0.00      0.00         4
  turkey-CoV       1.00      1.00      1.00        11

    accuracy                           0.97      2953
   macro avg       0.92      0.85      0.88      2953
weighted avg       0.97      0.97      0.97      2953

Accuracy score (test): 0.9739248222146969
Accuracy score (train): 0.9861556397551734
"""

# %%
# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/DC"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       0.94      0.93      0.94       119
   HCoV-HKU1       0.94      0.85      0.89        68
   HCoV-NL63       0.97      0.97      0.97       154
   HCoV-OC43       0.96      0.99      0.98       252
         IBV       1.00      0.99      0.99      2267
    MERS-CoV       1.00      0.96      0.98       198
   SARS-CoV2       0.89      1.00      0.94       624
     bat-CoV       1.00      0.92      0.96        13
  bovine-CoV       1.00      0.99      0.99       276
  canine-CoV       0.99      0.83      0.90       162
  equine-CoV       1.00      0.67      0.80         6
  feline-CoV       0.97      0.95      0.96       444
  ferret-CoV       1.00      0.73      0.84        11
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00       108
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.97      4743
   macro avg       0.98      0.90      0.94      4743
weighted avg       0.98      0.97      0.97      4743

Accuracy score (test): 0.9742778831962893
Accuracy score (train): 0.9812618810536797
"""

# %%
# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/DN"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       0.97      0.95      0.96       119
   HCoV-HKU1       0.98      0.90      0.94        68
   HCoV-NL63       0.97      0.99      0.98       154
   HCoV-OC43       0.97      0.99      0.98       252
         IBV       1.00      0.98      0.99      2267
    MERS-CoV       1.00      0.96      0.98       198
   SARS-CoV2       0.87      1.00      0.93       624
     bat-CoV       1.00      0.92      0.96        13
  bovine-CoV       0.99      0.99      0.99       276
  canine-CoV       0.99      0.83      0.90       162
  equine-CoV       1.00      0.67      0.80         6
  feline-CoV       0.98      0.96      0.97       444
  ferret-CoV       1.00      0.91      0.95        11
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00       108
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.97      4743
   macro avg       0.98      0.92      0.95      4743
weighted avg       0.98      0.97      0.98      4743

Accuracy score (test): 0.974910394265233
Accuracy score (train): 0.9829818050149361
"""
# Out:
#   Cell In[1], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/IC"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       0.94      0.93      0.94       119
   HCoV-HKU1       0.94      0.88      0.91        68
   HCoV-NL63       0.97      0.98      0.97       154
   HCoV-OC43       0.97      0.99      0.98       252
         IBV       1.00      0.98      0.99      2267
    MERS-CoV       1.00      0.95      0.97       198
   SARS-CoV2       0.87      1.00      0.93       624
     bat-CoV       1.00      0.92      0.96        13
  bovine-CoV       0.99      0.99      0.99       276
  canine-CoV       0.98      0.83      0.90       162
  equine-CoV       1.00      0.67      0.80         6
  feline-CoV       0.98      0.95      0.96       444
  ferret-CoV       1.00      0.82      0.90        11
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00       108
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.97      4743
   macro avg       0.98      0.91      0.94      4743
weighted avg       0.97      0.97      0.97      4743

Accuracy score (test): 0.9725911870124394
Accuracy score (train): 0.980266135602426
"""

# %%
# -----------------------------
# 1️⃣ Load known repeat patterns
files = []
folder = "proba2/IN"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                labels.append(parts[0])
                repeats.append(parts[1])

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

# -----------------------------
# 2️⃣ Load training data
files = []
folder = "trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(str(record.seq))
        labelTrain.append(file.replace("trainSet/", "").replace(".fasta", ""))

# -----------------------------
# 3️⃣ Load test data
files = []
folder = "testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTest = []
sequencesTest = []

for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(str(record.seq))
        labelTest.append(file.replace("testSet/", "").replace(".fasta", ""))

# -----------------------------
# 4️⃣ Feature extraction
def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]

# -----------------------------
# 5️⃣ Label encoding
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(labelTrain)
y_test_enc = encoder.transform(labelTest)

# -----------------------------
# 6️⃣ Remove small classes from training and test sets
class_counts = Counter(y_train_enc)
keep_classes = {cls for cls, count in class_counts.items() if count >= 3}
print(f"Keeping {len(keep_classes)} classes with ≥3 samples.")

# Filter training data
train_mask = np.array([label in keep_classes for label in y_train_enc])
X_train_np = np.array(X_train)[train_mask]
y_train_enc = np.array(y_train_enc)[train_mask]

# Filter test data using same classes
test_mask = np.array([label in keep_classes for label in y_test_enc])
X_test_np = np.array(X_test)[test_mask]
y_test_enc = np.array(y_test_enc)[test_mask]

# -----------------------------
# 7️⃣ Auto-adjust k_neighbors
min_class_size = min(Counter(y_train_enc).values())
safe_k = min(5, min_class_size)
print(f"Using k_neighbors = {safe_k}")

# -----------------------------
# 8️⃣ Train KNN
knn = KNeighborsClassifier(n_neighbors=safe_k, metric='minkowski')
knn.fit(X_train_np, y_train_enc)

# -----------------------------
# 9️⃣ Predict on test set
y_pred_enc = knn.predict(X_test_np)
y_pred = encoder.inverse_transform(y_pred_enc)
y_test = encoder.inverse_transform(y_test_enc)

print("Classification report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# 🔟 Predict on train set for train accuracy
y_pred_train_enc = knn.predict(X_train_np)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)
y_train = encoder.inverse_transform(y_train_enc)

print("Accuracy score (test):", accuracy_score(y_test, y_pred))
print("Accuracy score (train):", accuracy_score(y_train, y_pred_train))

# %%
"""
Classification report:
              precision    recall  f1-score   support

   HCoV-229E       0.94      0.96      0.95       119
   HCoV-HKU1       0.97      0.87      0.91        68
   HCoV-NL63       0.97      0.98      0.97       154
   HCoV-OC43       0.97      0.99      0.98       252
         IBV       1.00      0.98      0.99      2267
    MERS-CoV       1.00      0.95      0.98       198
   SARS-CoV2       0.89      1.00      0.94       624
     bat-CoV       1.00      0.85      0.92        13
  bovine-CoV       0.99      0.99      0.99       276
  canine-CoV       0.98      0.80      0.88       162
  equine-CoV       1.00      0.67      0.80         6
  feline-CoV       0.98      0.97      0.97       444
  ferret-CoV       1.00      0.91      0.95        11
hedgehog-CoV       1.00      1.00      1.00         5
 porcine-CoV       1.00      1.00      1.00       108
  rabbit-CoV       1.00      0.67      0.80         6
     rat-CoV       1.00      0.83      0.91         6
  turkey-CoV       1.00      0.96      0.98        24

    accuracy                           0.97      4743
   macro avg       0.98      0.91      0.94      4743
weighted avg       0.98      0.97      0.97      4743

Accuracy score (test): 0.9746995572422518
Accuracy score (train): 0.9822576265049334
"""

# %%
files = []
folder = "../proba2NoDuplicates/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))
# Out:
# Number of unique repeats: 1958
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.95      0.98        62
#    HCoV-HKU1       0.94      0.74      0.83        42
#    HCoV-NL63       1.00      0.95      0.97        74
#    HCoV-OC43       0.93      0.97      0.95       159
#          IBV       1.00      1.00      1.00      1242
#     MERS-CoV       0.97      0.99      0.98        87
#     SARS-CoV       0.00      0.00      0.00         2
#    SARS-CoV2       0.97      0.99      0.98       661
#      bat-CoV       0.67      1.00      0.80         4
#   bovine-CoV       0.99      0.96      0.97       161
#   canine-CoV       0.93      0.92      0.92        99
#  dolphin-CoV       0.00      0.00      0.00         2
#   equine-CoV       1.00      0.83      0.91         6
#   feline-CoV       0.98      0.99      0.99       270
#   ferret-CoV       0.25      0.62      0.36         8
# hedgehog-CoV       0.00      0.00      0.00         2
#  porcine-CoV       1.00      1.00      1.00        57
#   rabbit-CoV       1.00      0.67      0.80         6
#      rat-CoV       1.00      0.25      0.40         4
#   turkey-CoV       1.00      1.00      1.00        11
#
#     accuracy                           0.98      2959
#    macro avg       0.78      0.74      0.74      2959
# weighted avg       0.98      0.98      0.98      2959
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy score: 0.9780331192970598
# Accuracy score train: 0.9898078043098427

# %%
files = []
folder = "../proba2NoDuplicates/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNoDuplicates/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNoDuplicates"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNoDuplicates/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))
# Out:
# Number of unique repeats: 2511
# Classification report:
#               precision    recall  f1-score   support
#
#    HCoV-229E       1.00      0.92      0.96        62
#    HCoV-HKU1       0.97      0.81      0.88        42
#    HCoV-NL63       1.00      0.92      0.96        74
#    HCoV-OC43       0.96      0.96      0.96       159
#          IBV       1.00      0.99      1.00      1242
#     MERS-CoV       0.96      0.99      0.97        87
#     SARS-CoV       0.00      0.00      0.00         2
#    SARS-CoV2       0.95      0.99      0.97       661
#      bat-CoV       0.67      1.00      0.80         4
#   bovine-CoV       0.99      0.96      0.97       161
#   canine-CoV       0.91      0.87      0.89        99
#  dolphin-CoV       0.00      0.00      0.00         2
#   equine-CoV       1.00      0.83      0.91         6
#   feline-CoV       0.92      0.99      0.95       270
#   ferret-CoV       1.00      0.50      0.67         8
# hedgehog-CoV       0.00      0.00      0.00         2
#  porcine-CoV       1.00      1.00      1.00        57
#   rabbit-CoV       1.00      0.67      0.80         6
#      rat-CoV       0.00      0.00      0.00         4
#   turkey-CoV       1.00      1.00      1.00        11
#
#     accuracy                           0.97      2959
#    macro avg       0.77      0.72      0.73      2959
# weighted avg       0.97      0.97      0.97      2959
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pc/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy score: 0.9719499831023994
# Accuracy score train: 0.9866045428072219

# %%
files = []
folder = "../proba3/DC/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
# rezultati:
"""
Classification report: 
               precision    recall  f1-score   support

   /HCoV-229E       0.99      0.95      0.97       153
   /HCoV-HKU1       0.97      0.97      0.97        98
   /HCoV-NL63       0.99      0.98      0.98       213
   /HCoV-OC43       0.98      0.99      0.99       366
         /IBV       1.00      0.99      0.99      3150
    /MERS-CoV       1.00      0.98      0.99       395
    /SARS-CoV       0.75      1.00      0.86         3
   /SARS-CoV2       0.93      1.00      0.96      1360
     /bat-CoV       1.00      0.80      0.89        15
  /bovine-CoV       0.99      1.00      0.99       375
  /canine-CoV       0.98      0.92      0.95       218
 /dolphin-CoV       1.00      1.00      1.00         3
  /equine-CoV       1.00      0.57      0.73         7
  /feline-CoV       0.96      0.94      0.95       536
  /ferret-CoV       1.00      0.69      0.82        13
/hedgehog-CoV       1.00      1.00      1.00         6
 /porcine-CoV       1.00      1.00      1.00       132
  /rabbit-CoV       1.00      0.50      0.67         6
     /rat-CoV       1.00      0.38      0.55         8
  /turkey-CoV       1.00      0.89      0.94        27

     accuracy                           0.98      7084
    macro avg       0.98      0.88      0.91      7084
 weighted avg       0.98      0.98      0.98      7084

Accuracy score: 0.9798136645962733
Accuracy score train: 0.9882746051032807
"""

# %%
files = []
folder = "../proba3/DN/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
# rezultati:
"""
Classification report: 
               precision    recall  f1-score   support

   /HCoV-229E       1.00      0.96      0.98       153
   /HCoV-HKU1       0.99      0.97      0.98        98
   /HCoV-NL63       1.00      0.99      1.00       213
   /HCoV-OC43       0.99      0.99      0.99       366
         /IBV       1.00      0.98      0.99      3150
    /MERS-CoV       1.00      0.98      0.99       395
    /SARS-CoV       1.00      1.00      1.00         3
   /SARS-CoV2       0.93      1.00      0.96      1360
     /bat-CoV       1.00      0.87      0.93        15
  /bovine-CoV       0.99      1.00      1.00       375
  /canine-CoV       0.99      0.91      0.95       218
 /dolphin-CoV       1.00      1.00      1.00         3
  /equine-CoV       1.00      0.57      0.73         7
  /feline-CoV       0.99      0.98      0.98       536
  /ferret-CoV       1.00      0.85      0.92        13
/hedgehog-CoV       1.00      1.00      1.00         6
 /porcine-CoV       1.00      0.99      1.00       132
  /rabbit-CoV       1.00      0.50      0.67         6
     /rat-CoV       1.00      0.38      0.55         8
  /turkey-CoV       1.00      0.96      0.98        27

     accuracy                           0.98      7084
    macro avg       0.99      0.89      0.93      7084
 weighted avg       0.98      0.98      0.98      7084

Accuracy score: 0.9827780914737436
Accuracy score train: 0.9894896719319562
"""

# %%
files = []
folder = "../proba3/IN/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
# rezultati:
"""
Classification report: 
               precision    recall  f1-score   support

   /HCoV-229E       0.99      0.96      0.97       153
   /HCoV-HKU1       0.98      0.97      0.97        98
   /HCoV-NL63       1.00      0.98      0.99       213
   /HCoV-OC43       0.98      0.99      0.99       366
         /IBV       1.00      0.98      0.99      3150
    /MERS-CoV       1.00      0.97      0.99       395
    /SARS-CoV       0.75      1.00      0.86         3
   /SARS-CoV2       0.92      1.00      0.96      1360
     /bat-CoV       1.00      0.73      0.85        15
  /bovine-CoV       1.00      0.99      1.00       375
  /canine-CoV       0.98      0.92      0.95       218
 /dolphin-CoV       1.00      1.00      1.00         3
  /equine-CoV       1.00      0.57      0.73         7
  /feline-CoV       0.98      0.95      0.97       536
  /ferret-CoV       1.00      0.85      0.92        13
/hedgehog-CoV       1.00      1.00      1.00         6
 /porcine-CoV       1.00      1.00      1.00       132
  /rabbit-CoV       1.00      0.67      0.80         6
     /rat-CoV       1.00      0.38      0.55         8
  /turkey-CoV       1.00      0.89      0.94        27

     accuracy                           0.98      7084
    macro avg       0.98      0.89      0.92      7084
 weighted avg       0.98      0.98      0.98      7084
 Accuracy score: 0.9802371541501976
 Accuracy score train: 0.9880315917375455
"""

# %%
files = []
folder = "../proba3/IC/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl/"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

# %%
# rezultati:
"""
Classification report: 
               precision    recall  f1-score   support

   /HCoV-229E       0.98      0.96      0.97       153
   /HCoV-HKU1       0.99      0.97      0.98        98
   /HCoV-NL63       1.00      0.98      0.99       213
   /HCoV-OC43       0.98      0.99      0.99       366
         /IBV       1.00      0.99      0.99      3150
    /MERS-CoV       1.00      0.96      0.98       395
    /SARS-CoV       1.00      1.00      1.00         3
   /SARS-CoV2       0.93      1.00      0.96      1360
     /bat-CoV       1.00      0.80      0.89        15
  /bovine-CoV       1.00      1.00      1.00       375
  /canine-CoV       0.98      0.93      0.95       218
 /dolphin-CoV       1.00      1.00      1.00         3
  /equine-CoV       1.00      0.57      0.73         7
  /feline-CoV       0.98      0.97      0.98       536
  /ferret-CoV       1.00      0.85      0.92        13
/hedgehog-CoV       1.00      1.00      1.00         6
 /porcine-CoV       1.00      0.99      1.00       132
  /rabbit-CoV       1.00      0.50      0.67         6
     /rat-CoV       1.00      0.38      0.55         8
  /turkey-CoV       1.00      0.89      0.94        27

     accuracy                           0.98      7084
    macro avg       0.99      0.89      0.92      7084
 weighted avg       0.98      0.98      0.98      7084
 Accuracy score: 0.9823546019198193
 Accuracy score train: 0.9889428918590523
"""

# %% [markdown]
# # OVO BOLJE BEZ OVERSAMPLINGA

# %%
files = []
folder = "../proba2/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSet/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSet/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

print("Classification report: ")
report = classification_report(y_test, y_pred)
print(report)

y_pred_train_enc = knn.predict(X_train)
y_pred_train = encoder.inverse_transform(y_pred_train_enc)

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
print("Accuracy score train: " + str(accuracy_score(y_train, y_pred_train)))

with open("classification_report_knn_direct.txt", "w") as f:
    f.write(report)
    f.write("\nAccuracy score: ")
    f.write(str(accuracy_score(y_test, y_pred)))
    f.write("\nAccuracy score train: ")
    f.write(str(accuracy_score(y_train, y_pred_train)))
# Out:
# Number of unique repeats: 2210

# %%
files = []
folder = "../proba2/direct"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSet/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSet/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 798
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       0.98      0.99      0.99       395
#     SARS-CoV       0.75      1.00      0.86         3
#      bat-CoV       1.00      0.88      0.93        16
#   bovine-CoV       1.00      0.99      0.99       378
#   canine-CoV       0.95      0.96      0.96       219
#   feline-CoV       0.98      0.99      0.98       536
# hedgehog-CoV       1.00      0.83      0.91         6
#  porcine-CoV       1.00      1.00      1.00       132
#
#     accuracy                           0.98      1685
#    macro avg       0.96      0.95      0.95      1685
# weighted avg       0.98      0.98      0.98      1685
#
# Accuracy score: 0.9827893175074184

# %%
files = []
folder = "../proba2/indirect"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSet/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSet"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSet/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 1007
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       0.99      0.98      0.98       395
#     SARS-CoV       0.75      1.00      0.86         3
#      bat-CoV       1.00      0.88      0.93        16
#   bovine-CoV       1.00      0.98      0.99       378
#   canine-CoV       0.97      0.95      0.96       219
#   feline-CoV       0.96      0.99      0.97       536
# hedgehog-CoV       1.00      1.00      1.00         6
#  porcine-CoV       1.00      0.99      1.00       132
#
#     accuracy                           0.98      1685
#    macro avg       0.96      0.97      0.96      1685
# weighted avg       0.98      0.98      0.98      1685
#
# Accuracy score: 0.9786350148367953

# %%
files = []
folder = "../proba3/DC"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 4335
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       1.00      0.99      0.99       395
#     SARS-CoV       1.00      1.00      1.00         3
#      bat-CoV       1.00      0.73      0.85        15
#   bovine-CoV       0.99      0.99      0.99       375
#   canine-CoV       0.98      0.95      0.97       218
#   feline-CoV       0.96      0.99      0.98       536
# hedgehog-CoV       1.00      0.83      0.91         6
#  porcine-CoV       1.00      1.00      1.00       132
#
#     accuracy                           0.98      1680
#    macro avg       0.99      0.94      0.96      1680
# weighted avg       0.98      0.98      0.98      1680
#
# Accuracy score: 0.9839285714285714

# %%
files = []
folder = "../proba3/DN"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 6309
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       1.00      0.99      1.00       395
#     SARS-CoV       1.00      1.00      1.00         3
#      bat-CoV       1.00      0.93      0.97        15
#   bovine-CoV       0.99      1.00      1.00       375
#   canine-CoV       0.99      0.96      0.98       218
#   feline-CoV       0.98      0.99      0.99       536
# hedgehog-CoV       1.00      1.00      1.00         6
#  porcine-CoV       1.00      1.00      1.00       132
#
#     accuracy                           0.99      1680
#    macro avg       1.00      0.99      0.99      1680
# weighted avg       0.99      0.99      0.99      1680
#
# Accuracy score: 0.9916666666666667

# %%
files = []
folder = "../proba3/IC"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 5163
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       1.00      0.99      1.00       395
#     SARS-CoV       1.00      1.00      1.00         3
#      bat-CoV       1.00      0.67      0.80        15
#   bovine-CoV       0.99      1.00      0.99       375
#   canine-CoV       0.99      0.93      0.96       218
#   feline-CoV       0.96      0.99      0.98       536
# hedgehog-CoV       1.00      1.00      1.00         6
#  porcine-CoV       1.00      1.00      1.00       132
#
#     accuracy                           0.98      1680
#    macro avg       0.99      0.95      0.97      1680
# weighted avg       0.98      0.98      0.98      1680
#
# Accuracy score: 0.9845238095238096

# %%
files = []
folder = "../proba3/IN"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labels = []
repeats = []

# Read data from each file
for file in files:
    with open(file, "r") as f:
        for line in f:
            parts = line.strip().split(",")
            if len(parts) >= 2:
                label = parts[0]
                repeat = parts[1]
                labels.append(label)
                repeats.append(repeat)

files = []
folder = "../trainSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)

labelTrain = []
sequencesTrain = []

# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTrain.append(record.seq)
        labelTrain.append(file.replace("../trainSetNucl/", "").replace(".fasta", ""))

labelTest = []
sequencesTest = []

files = []
folder = "../testSetNucl"

for file in os.listdir(folder):
    if file.startswith("."):
        continue
    files.append(folder + "/" + file)


# Read data from each file
for file in files:
    records = SeqIO.parse(file, "fasta")
    for record in records:
        sequencesTest.append(record.seq)
        labelTest.append(file.replace("../testSetNucl/", "").replace(".fasta", ""))

known_repeats = list(set(repeats))
print(f"Number of unique repeats: {len(known_repeats)}")

def extract_repeat_counts(sequence, repeat_list):
    return [sequence.count(r) for r in repeat_list]

X_train = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTrain]
y_train = labelTrain

X_test = [extract_repeat_counts(seq, known_repeats) for seq in sequencesTest]
y_test = labelTest

# LightGBM zahteva da i oznake budu brojevi, pa ih je potrebno enkodirati tako
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski')  # Euclidean by default

# 3️⃣ Fit
knn.fit(X_train, y_train_enc)

# 4️⃣ Predict
y_pred_enc = knn.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# 5️⃣ Evaluate
print("Report: ")
print(classification_report(y_test, y_pred))

print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Number of unique repeats: 4897
# Report:
#               precision    recall  f1-score   support
#
#     MERS-CoV       1.00      0.98      0.99       395
#     SARS-CoV       1.00      1.00      1.00         3
#      bat-CoV       1.00      0.73      0.85        15
#   bovine-CoV       0.99      1.00      0.99       375
#   canine-CoV       0.99      0.91      0.95       218
#   feline-CoV       0.95      1.00      0.97       536
# hedgehog-CoV       1.00      1.00      1.00         6
#  porcine-CoV       1.00      1.00      1.00       132
#
#     accuracy                           0.98      1680
#    macro avg       0.99      0.95      0.97      1680
# weighted avg       0.98      0.98      0.98      1680
#
# Accuracy score: 0.9809523809523809
